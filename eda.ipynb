# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Adding csv file

# %%
data=pd.read_csv('data2.csv')

# %% [markdown]
# ### Basic information about dataset

# %%
data
# Out:
#      Age  Projects Completed  Productivity (%)  Satisfaction Rate (%)  \
# 0     25                  11                57                     25
# 1     59                  19                55                     76
# 2     30                   8                87                     10
# 3     26                   1                53                      4
# 4     43                  14                 3                      9
# ..   ...                 ...               ...                    ...
# 195   29                   9                32                     87
# 196   26                   7                45                     28
# 197   22                   3                36                     77
# 198   36                  23                96                     50
# 199   43                  10                86                     71
#
#      Feedback Score  Salary
# 0               4.7   63596
# 1               2.8  112540
# 2               2.4   66292
# ...

# %%
data.shape
# Out:
# (200, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    200 non-null    int64
#  1   Projects Completed     200 non-null    int64
#  2   Productivity (%)       200 non-null    int64
#  3   Satisfaction Rate (%)  200 non-null    int64
#  4   Feedback Score         200 non-null    float64
#  5   Salary                 200 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 9.5 KB

# %%
data.describe()
# Out:
#               Age  Projects Completed  Productivity (%)  \
# count  200.000000          200.000000        200.000000
# mean    34.650000           11.455000         46.755000
# std      9.797318            6.408849         28.530068
# min     22.000000            0.000000          0.000000
# 25%     26.000000            6.000000         23.000000
# 50%     32.000000           11.000000         45.000000
# 75%     41.000000           17.000000         70.000000
# max     60.000000           25.000000         98.000000
#
#        Satisfaction Rate (%)  Feedback Score         Salary
# count             200.000000      200.000000     200.000000
# mean               49.935000        2.883000   76619.245000
# std                28.934353        1.123263   27082.299202
# min                 0.000000        1.000000   30231.000000
# 25%                25.750000        1.900000   53080.500000
# 50%                50.500000        2.800000   80540.000000
# ...

# %%
data.head()
# Out:
#    Age  Projects Completed  Productivity (%)  Satisfaction Rate (%)  \
# 0   25                  11                57                     25
# 1   59                  19                55                     76
# 2   30                   8                87                     10
# 3   26                   1                53                      4
# 4   43                  14                 3                      9
#
#    Feedback Score  Salary
# 0             4.7   63596
# 1             2.8  112540
# 2             2.4   66292
# 3             1.4   38303
# 4             4.5  101133

# %%
data.tail()
# Out:
#      Age  Projects Completed  Productivity (%)  Satisfaction Rate (%)  \
# 195   29                   9                32                     87
# 196   26                   7                45                     28
# 197   22                   3                36                     77
# 198   36                  23                96                     50
# 199   43                  10                86                     71
#
#      Feedback Score  Salary
# 195             3.5   50051
# 196             2.8   46612
# 197             1.6   32992
# 198             3.4  104216
# 199             2.0  104341

# %%
data.sample(10)
# Out:
#      Age  Projects Completed  Productivity (%)  Satisfaction Rate (%)  \
# 84    57                  23                 2                     94
# 107   44                  24                67                     91
# 8     30                   7                32                     43
# 114   55                  19                41                     87
# 53    44                  16                60                     80
# 96    51                  24                75                     37
# 175   24                  10                69                     62
# 104   31                   9                80                     13
# 180   25                   6                 2                     43
# 196   26                   7                45                     28
#
#      Feedback Score  Salary
# 84              3.7  111381
# 107             4.0  104209
# 8               2.3   49323
# 114             3.1  110104
# 53              3.2   80976
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Projects Completed', 'Productivity (%)',
#        'Satisfaction Rate (%)', 'Feedback Score', 'Salary'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Age                        int64
# Projects Completed         int64
# Productivity (%)           int64
# Satisfaction Rate (%)      int64
# Feedback Score           float64
# Salary                     int64
# dtype: object

# %% [markdown]
# ### checking for incomplete and duplicate data

# %%
data.isnull().sum()
# Out:
# Age                      0
# Projects Completed       0
# Productivity (%)         0
# Satisfaction Rate (%)    0
# Feedback Score           0
# Salary                   0
# dtype: int64

# %%
copy=data.duplicated().sum()
copy
# Out:
# 0

# %%
data.shape
# Out:
# (200, 6)

# %% [markdown]
# ## Data Analysis

# %%
bins = [0,5, 10, 15, 20, 25,30]
labels = ['0-5', '5-10', '10-15', '15-20', '20-25','25-30']

data['Projects Completed_Binned'] = pd.cut(data['Projects Completed'], bins=bins,labels=labels,right=False)
plt.figure(figsize=(10, 5))

sns.histplot(x='Projects Completed_Binned', data=data, hue='Productivity (%)')

plt.xlabel('Projects Completed')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### -->  When the number of projects completed reaches around 20-25, productivity improves drastically.

# %%
bins = [0,20,40,60,80,100]
labels = ['0-20', '20-40', '40-60', '60-80','80-100']

data['Satisfaction_Binned'] = pd.cut(data['Satisfaction Rate (%)'], bins=bins, labels=labels, right=False)

plt.figure(figsize=(10, 5))
sns.countplot(x='Satisfaction_Binned',data=data,hue='Productivity (%)')

plt.xlabel('Satisfaction Rate (%) ')
plt.ylabel(' ')

plt.show()

# %% [markdown]
# ### -->even with low satisfaction rate ,productivity is high

# %%
bins = [20, 30, 40, 50, 60]
labels = ['20-30', '30-40', '40-50', '50-60']

data['Age_Binned'] = pd.cut(data['Age'], bins=bins, labels=labels, right=False)

plt.figure(figsize=(10, 5))
sns.histplot(x='Age_Binned', data=data, hue='Productivity (%)')

plt.xlabel('Age')
plt.ylabel(' ')

plt.show()

# %% [markdown]
# ### --> the age group of 30-40 is having higher productivity

# %%
bins = [30000, 60000, 90000, 120000]

labels = ['30000-60000', '60000-90000', '90000-120000']


data['Salary_Binned'] = pd.cut(data['Salary'], bins=bins, labels=labels, right=False)


plt.figure(figsize=(10, 5))
sns.countplot(x='Salary_Binned', data=data, hue='Productivity (%)')
plt.xlabel('Salary')
plt.show()

# %% [markdown]
# ### --> Productivity does not depend heavily on salary

# %%
x = data.drop(['Age_Binned','Salary_Binned','Projects Completed_Binned'], axis=1)
x=x.drop(['Satisfaction_Binned'],axis=1)
x
# Out:
#      Age  Projects Completed  Productivity (%)  Satisfaction Rate (%)  \
# 0     25                  11                57                     25
# 1     59                  19                55                     76
# 2     30                   8                87                     10
# 3     26                   1                53                      4
# 4     43                  14                 3                      9
# ..   ...                 ...               ...                    ...
# 195   29                   9                32                     87
# 196   26                   7                45                     28
# 197   22                   3                36                     77
# 198   36                  23                96                     50
# 199   43                  10                86                     71
#
#      Feedback Score  Salary
# 0               4.7   63596
# 1               2.8  112540
# 2               2.4   66292
# ...

# %% [markdown]
# ### heatmap

# %%
correlation = x.corr()
plt.figure(figsize=(5,5))

sns.heatmap(correlation, annot=True, cmap='coolwarm', xticklabels=correlation.columns, yticklabels=correlation.columns)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# salary and age have a strong correlation.
# project completed and salary have a strong correlation.
# age and project completed have a strong correlation.

# %%
sns.relplot(x='Projects Completed', y='Salary', hue='Productivity (%)', data=data)
plt.xlabel('Projects Completed')
plt.ylabel('salary')

plt.show()

# %%
sns.relplot(x='Age', y='Salary', hue='Productivity (%)', data=data)
plt.xlabel('Age')
plt.ylabel('salary')

plt.show()

# %%
sns.relplot(x='Salary',y='Age',hue='Productivity (%)',data=data)
plt.xlabel('salary')
plt.ylabel('age')
plt.show()

# %% [markdown]
# ### --> all factors have linear variation

# %% [markdown]
# ### pairplot

# %%
sns.pairplot(x, hue='Productivity (%)', kind='scatter')
plt.show()
